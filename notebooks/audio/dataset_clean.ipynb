# %% [markdown]
# разбор датасета на ру и енг

# %% [markdown]
# ## Анализ музыкального датасета Spotify
#
# Перед извлечением пользовательских предпочтений проводится анализ музыкального
# датасета Spotify (1921–2020) с целью определения допустимых языков треков и
# жанров, представленных в данных.

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d maharshipandya/-spotify-tracks-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset
# License(s): ODbL-1.0
# Downloading -spotify-tracks-dataset.zip to /content
#   0% 0.00/8.17M [00:00<?, ?B/s]
# 100% 8.17M/8.17M [00:00<00:00, 1.00GB/s]

# %%
# !unzip spotify-dataset-1921-2020-160k-tracks.zip -d dataset_a
# !unzip spotify-tracks-dataset.zip -d dataset_b
# Out:
# Archive:  spotify-dataset-1921-2020-160k-tracks.zip
# replace dataset_a/data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: dataset_a/data.csv
#   inflating: dataset_a/data_by_artist.csv
#   inflating: dataset_a/data_by_genres.csv
#   inflating: dataset_a/data_by_year.csv
#   inflating: dataset_a/data_w_genres.csv
# Archive:  spotify-tracks-dataset.zip
#   inflating: dataset_b/dataset.csv

# %%
# !ls dataset_a
# !ls dataset_b
# Out:
# data_by_artist.csv  data_by_year.csv  data_w_genres.csv
# data_by_genres.csv  data.csv
# dataset.csv

# %%
df_tracks = pd.read_csv("dataset_a/data.csv")
df_tracks.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo'],
#       dtype='object')

# %%
import pandas as pd

df_tracks = pd.read_csv("tracks.csv")
df_artists = pd.read_csv("artists.csv")

# %%
df_tracks.columns
# Out:
# Index(['artist', 'artist_spotify_id', 'name', 'spotify_id', 'duration_ms',
#        'explicit', 'popularity', 'album_type', 'album_name',
#        'album_spotify_id', 'release_date', 'album_popularity', 'key', 'mode',
#        'time_signature', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence',
#        'tempo'],
#       dtype='object')

# %%
df_artists.columns
# Out:
# Index(['Unnamed: 0', 'artist', 'musicbrainz_id', 'spotify_id', 'type',
#        'followers', 'genres', 'popularity'],
#       dtype='object')

# %%
def norm(s):
    return str(s).lower().strip()

df_tracks["artist_norm"] = df_tracks["artist"].apply(norm)
df_artists["artist_norm"] = df_artists["artist"].apply(norm)

# %%
df_artists_genres = df_artists[["artist_norm", "genres"]].copy()

# %%
df_merged = pd.merge(
    df_tracks,
    df_artists_genres,
    on="artist_norm",
    how="left"
)

# %%
df_merged = df_merged.drop(columns=["artist_norm"])

# %%
df_merged["spotify_id"].isna().mean()
# Out:
# np.float64(0.0)

# %%
df_merged["genres"].notna().mean()
# Out:
# np.float64(0.9956231903575516)

# %%
df_merged[["spotify_id", "artist", "name", "genres"]].head(10)
# Out:
#                spotify_id           artist  \
# 0  2LMKbv1STyxCLz4C4yY90M  Николай Матвеев
# 1  67IbCSYPS0PlGo6wuxOilm  Николай Матвеев
# 2  1iymFuEk462JYmTqSIpCft  Николай Матвеев
# 3  6VKiBpnzgMukq9moEHT0yk  Николай Матвеев
# 4  1cyNhNBRyUpXAdk3RAz2gd  Николай Матвеев
# 5  5ZHdjO8Bf8lJ3RbepT46jG  Николай Матвеев
# 6  67Eljns70f1HVVDc3KQTkr  Николай Матвеев
# 7  35B0MVFkKgreGWRTrQT7Bc  Николай Матвеев
# 8  6CmcEf67THXXLufIiNDdl3  Николай Матвеев
# 9  5mJpVEbIwUnGtEFvcDtB7d  Николай Матвеев
#
#                                  name genres
# 0  Концерт No. 34 "Да воскреснет Бог"     []
# 1                         Господи сил     []
# 2           Разбойника благоразумного     []
# 3    Крест - хранитель всея вселенныя     []
# 4              Спаси, Боже, люди Твоя     []
# 5  Сей день / Прокимен в неделю Пасхи     []
# 6                 Вечери твоея тайныя     []
# 7                 Ирмосы Святой Пасхи     []
# 8                         Жив Господь     []
# 9                    Воскресения день     []

# %%
df_merged.to_csv("tracks_with_genres.csv", index=False)

# %%
df_merged.columns
# Out:
# Index(['artist', 'artist_spotify_id', 'name', 'spotify_id', 'duration_ms',
#        'explicit', 'popularity', 'album_type', 'album_name',
#        'album_spotify_id', 'release_date', 'album_popularity', 'key', 'mode',
#        'time_signature', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence',
#        'tempo', 'genres'],
#       dtype='object')

# %%
df_dataset.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artist', 'album_name', 'name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'genres'],
#       dtype='object')

# %%
df_dataset = pd.read_csv("dataset_b/dataset.csv")

df_dataset = df_dataset.drop(columns=["Unnamed: 0"], errors="ignore")

# %%
df_dataset = df_dataset.rename(columns={
    "artists": "artist",
    "track_name": "name",
    "track_genre": "genres"
})

# %%
df_dataset.columns
# Out:
# Index(['spotify_id', 'artist', 'album_name', 'name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'genres'],
#       dtype='object')

# %%
for col in df_merged.columns:
    if col not in df_dataset.columns:
        df_dataset[col] = pd.NA

# %%
df_dataset_aligned = df_dataset[df_merged.columns].copy()

# %%
existing_ids = set(df_merged["spotify_id"].dropna())

df_dataset_new = df_dataset_aligned[
    ~df_dataset_aligned["spotify_id"].isin(existing_ids)
].copy()

# %%
df_full = pd.concat(
    [df_merged, df_dataset_new],
    ignore_index=True
)

# %%
df_full["spotify_id"].duplicated().sum()

df_merged.shape, df_dataset_new.shape, df_full.shape
# Out:
# ((44553, 25), (112932, 25), (157485, 25))

# %%
df_full.to_csv("tracks_full_unified.csv", index=False)

# %%
df_tracks = pd.read_csv("dataset_a/data.csv")

# %%
df_genres = pd.read_csv("dataset_a/data_by_genres.csv")

# %%
df_tracks.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo'],
#       dtype='object')

# %%
df_genres.columns
# Out:
# Index(['mode', 'genres', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'popularity', 'key'],
#       dtype='object')

# %%
FEATURES = [
    "energy",
    "loudness",
    "danceability",
    "valence",
    "tempo",
    "acousticness",
    "instrumentalness",
    "liveness",
    "speechiness"
]

# %%
df_tracks_feat = df_tracks.dropna(subset=FEATURES).copy()
df_genres_feat = df_genres.dropna(subset=FEATURES).copy()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_tracks_feat[FEATURES] = scaler.fit_transform(df_tracks_feat[FEATURES])
df_genres_feat[FEATURES] = scaler.transform(df_genres_feat[FEATURES])

# %%
from sklearn.metrics.pairwise import cosine_distances
import numpy as np

genre_vectors = df_genres_feat[FEATURES].values
track_vectors = df_tracks_feat[FEATURES].values

distances = cosine_distances(track_vectors, genre_vectors)

nearest_genre_idx = np.argmin(distances, axis=1)

df_tracks_feat["genres"] = df_genres_feat.iloc[nearest_genre_idx]["genres"].values

# %%
df_tracks = df_tracks.merge(
    df_tracks_feat[["id", "genres"]],
    on="id",
    how="left"
)

# %%
df_tracks["genres"].notna().mean()
# Out:
# np.float64(1.0)

# %%
df_tracks[["artists", "name", "genres"]].head(20)
# Out:
#                                               artists  \
# 0   ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 1                                      ['Dennis Day']
# 2   ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# 3                                    ['Frank Parker']
# 4                                      ['Phil Regan']
# 5   ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# 6                                  ['John McCormack']
# 7                             ['Sergei Rachmaninoff']
# 8                                 ['Ignacio Corsini']
# 9                                         ['Fortugé']
# 10                              ['Maurice Chevalier']
# 11                                ['Ignacio Corsini']
# 12                                        ['Georgel']
# 13                                ['Mehmet Kemiksiz']
# 14                                     ['Zay Gatsby']
# 15             ['Sergei Rachmaninoff', 'Ruth Laredo']
# 16                                     ['Phil Regan']
# 17             ['Hector Berlioz', 'Arturo Toscanini']
# 18                                        ['THE GUY']
# 19                              ['Christopher Lynch']
#
#                                                  name                 genres
# 0   Piano Concerto No. 3 in D Minor, Op. 30: III. ...            polish jazz
# 1                             Clancy Lowered the Boom             coverchill
# 2                                           Gati Bali             drone folk
# 3                                           Danny Boy                 papuri
# 4                         When Irish Eyes Are Smiling     classic eurovision
# 5                                        Gati Mardika     swedish indie folk
# 6                            The Wearing of the Green              pei indie
# 7   Morceaux de fantaisie, Op. 3: No. 2, Prélude i...  czech classical piano
# 8                         La Mañanita - Remasterizado   south african choral
# 9                                   Il Etait Syndiqué             music hall
# 10                    Dans La Vie Faut Pas S'en Faire                  gypsy
# 11                 Por Que Me Dejaste - Remasterizado   japanese traditional
# 12                                          La Vipère      christmas product
# 13                                         Ud Taksimi              esperanto
# 14                                     Power Is Power          rock keyboard
# 15  10 Préludes, Op. 23: No. 5 in G Minor. Alla ma...      contemporary jazz
# 16                                  Come Back To Erin          italian tenor
# 17                                      Rákóczy March            jazz violin
# 18                                        When We Die        ann arbor indie
# 19                                 A Ballynure Ballad  american folk revival

# %%
df_tracks
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# 170648  ['Anuel AA', 'Daddy Yankee', 'KAROL G', 'Ozuna...         0.786
# 170649                                       ['Ashnikko']         0.717
# 170650                                        ['MAMAMOO']         0.634
# 170651                                         ['Eminem']         0.671
# 170652                              ['KEVVO', 'J Balvin']         0.856
#
#         duration_ms  energy  explicit                      id  \
# 0            831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz
# 1            180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8
# 2            500062   0.166         0  1o6I8BglA6ylDMrIELygv1
# 3            210000   0.309         0  3ftBPsC5vPBKxYSee08FDH
# 4            166693   0.193         0  4d6HGyGT8e121BsdKmw9v6
# ...             ...     ...       ...                     ...
# 170648       301714   0.808         0  0KkIkfsLEJbrcIhYsCL7L5
# 170649       150654   0.753         0  0OStKKAuXlxA0fMH54Qs6E
# 170650       211280   0.858         0  4BZXVFYCb76Q0Klojq4piV
# 170651       337147   0.623         1  5SiZJoLXp3WOl3J4C8IK0d
# 170652       189507   0.721         1  7HmnJHfs0BkFzX4x8j0hkl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.878000   10    0.6650   -20.096     1
# 1               0.000000    7    0.1600   -12.441     1
# 2               0.913000    3    0.1010   -14.850     1
# 3               0.000028    5    0.3810    -9.316     1
# 4               0.000002    3    0.2290   -10.096     1
# ...                  ...  ...       ...       ...   ...
# 170648          0.000289    7    0.0822    -3.702     1
# 170649          0.000000    7    0.1010    -6.020     1
# 170650          0.000009    4    0.2580    -2.226     0
# 170651          0.000008    2    0.6430    -7.161     1
# 170652          0.004710    7    0.1820    -4.928     1
#
#                                                      name  popularity  \
# 0       Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 1                                 Clancy Lowered the Boom           5
# 2                                               Gati Bali           5
# 3                                               Danny Boy           3
# 4                             When Irish Eyes Are Smiling           2
# ...                                                   ...         ...
# 170648                                              China          72
# 170649                        Halloweenie III: Seven Days          68
# 170650                                                AYA          76
# 170651                                           Darkness          70
# 170652                    Billetes Azules (with J Balvin)          74
#
#        release_date  speechiness    tempo              genres
# 0              1921       0.0366   80.954         polish jazz
# 1              1921       0.4150   60.936          coverchill
# 2              1921       0.0339  110.339          drone folk
# 3              1921       0.0354  100.109              papuri
# 4              1921       0.0380  101.665  classic eurovision
# ...             ...          ...      ...                 ...
# 170648   2020-05-29       0.0881  105.029     trap venezolano
# 170649   2020-10-23       0.0605  137.936        funky breaks
# 170650   2020-11-03       0.0809   91.688        sacred steel
# 170651   2020-01-17       0.3080   75.055       naija worship
# 170652   2020-10-16       0.1080   94.991     texas latin rap
#
# [170653 rows x 20 columns]

# %%
df_tracks.to_csv("tracks_with_genres_filled.csv", index=False)

# %%
df_full = pd.read_csv(
    "tracks_full_unified.csv",
    low_memory=False
)

# %%
df_full.columns
# Out:
# Index(['artist', 'artist_spotify_id', 'name', 'spotify_id', 'duration_ms',
#        'explicit', 'popularity', 'album_type', 'album_name',
#        'album_spotify_id', 'release_date', 'album_popularity', 'key', 'mode',
#        'time_signature', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence',
#        'tempo', 'genres'],
#       dtype='object')

# %%
df_filled = pd.read_csv(
    "tracks_with_genres_filled.csv",
    low_memory=False
)

df_filled.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo', 'genres'],
#       dtype='object')

# %%
set(df_full.columns) - set(df_filled.columns)
# Out:
# {'album_name',
#  'album_popularity',
#  'album_spotify_id',
#  'album_type',
#  'artist',
#  'artist_spotify_id',
#  'spotify_id',
#  'time_signature'}

# %%
set(df_filled.columns) - set(df_full.columns)
# Out:
# {'artists', 'id', 'year'}

# %%
df_filled = df_filled.rename(columns={
    "id": "spotify_id",
    "artists": "artist"
})

# %%
df_filled = df_filled.drop(columns=["year"], errors="ignore")

# %%
for col in df_full.columns:
    if col not in df_filled.columns:
        df_filled[col] = pd.NA

# %%
df_filled = df_filled[df_full.columns]

# %%
existing_ids = set(df_full["spotify_id"].dropna())

df_filled_new = df_filled[
    ~df_filled["spotify_id"].isin(existing_ids)
].copy()

# %%
df_final = pd.concat(
    [df_full, df_filled_new],
    ignore_index=True
)
# Out:
# /tmp/ipython-input-2884984460.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_final = pd.concat(

# %%
df_final["spotify_id"].duplicated().sum()

df_full.shape, df_filled_new.shape, df_final.shape
# Out:
# ((157485, 25), (162095, 25), (319580, 25))

# %%
df_final.to_csv("tracks_final_ready.csv", index=False)

# %%
import re

def parse_artists(raw):
    if not isinstance(raw, str):
        return []

    s = raw.lower()

    s = re.sub(r"\([^)]*\)", "", s)
    s = re.sub(r"\[[^\]]*\]", "", s)
    s = re.sub(r"\{[^}]*\}", "", s)

    separators = [
        r"\s+feat\.?\s+",
        r"\s+ft\.?\s+",
        r"\s+featuring\s+",
        r"\s*&\s*",
        r"\s*,\s*",
        r"\s*/\s*",
        r"\s+x\s+",
    ]

    for sep in separators:
        s = re.sub(sep, ";", s)

    artists = [a.strip() for a in s.split(";") if a.strip()]
    return artists

# %%
import pandas as pd
import ast

df = pd.read_csv("tracks_final_ready.csv")

def parse_genres(x):
    try:
        return ast.literal_eval(x)
    except:
        return []

df["genres_parsed"] = df["genres"].apply(parse_genres)

df["artist_list"] = df["artist"].apply(parse_artists)

df_exploded = df.explode("artist_list").rename(
    columns={"artist_list": "artist_clean"}
)

df_exploded = df_exploded.dropna(subset=["artist_clean"])
# Out:
# /tmp/ipython-input-2871240696.py:4: DtypeWarning: Columns (1,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("tracks_final_ready.csv")

# %%
artists_unique = (
    df_exploded
    .groupby("artist_clean")
    .agg(
        genres=("genres_parsed", lambda x: sorted(set(g for sub in x for g in sub))),
        avg_instrumentalness=("instrumentalness", "mean"),
        max_instrumentalness=("instrumentalness", "max"),
        tracks_count=("spotify_id", "count"),
    )
    .reset_index()
)

# %%
artists_unique["language"] = None
artists_unique["instrumental"] = None
artists_unique["notes"] = None

# %%
artists_unique.to_csv(
    "artists_unique_normalized.csv",
    index=False
)

# %%
artists = pd.read_csv("artists_unique_normalized.csv")

# %%
def has_cyrillic(text):
    if not isinstance(text, str):
        return False
    return bool(re.search(r"[А-Яа-яЁё]", text))

# %%
def has_chinese(text):
    if not isinstance(text, str):
        return False
    return bool(re.search(r"[\u4e00-\u9fff]", text))

# %%
def detect_language_simple(name):
    if has_cyrillic(name):
        return "ru"
    if has_chinese(name):
        return "china"
    return "other"

# %%
artists["language_auto"] = artists["artist_clean"].apply(detect_language_simple)

# %%
artists["language_auto"].value_counts()
# Out:
# language_auto
# other    32963
# ru        1770
# china      202
# Name: count, dtype: int64

# %%
artists[artists["language_auto"] == "ru"].sample(20)
# Out:
#                            artist_clean  \
# 33046  александр сергеевич даргомыжский
# 33384                  владимир винокур
# 33424      восточный скоростной диаметр
# 33690                      иван смирнов
# 33333                  василий петренко
# 33112                            альянс
# 34537                             троин
# 33764                          калигари
# 34432                            сказка
# 33249                        белый орёл
# 33413           вокальное трио "реликт"
# 33978                  маша малиновская
# 33754                   исходный разрыв
# 34586                          хелависа
# 34448                    сны моего неба
# 34323                              ромс
# 34334                    русский футбол
# 33389              владимир жириновский
# 34299                            рарогъ
# 33131                  анатолий крупнов
#
#                                                   genres  \
# 33046                            ['russian romanticism']
# 33384                                                 []
# 33424                                                 []
# 33690                                                 []
# 33333  ['classical performance', 'orchestral performa...
# 33112      ['classic russian rock', 'russian post-punk']
# 34537                             ['russian folk metal']
# 33764  ['argentine rock', 'latin alternative', 'latin...
# 34432  ['russian pop', 'ukrainian pop', 'ukrainian ro...
# 33249         ['classic russian pop', 'russian chanson']
# 33413                                                 []
# 33978                                                 []
# 33754                                                 []
# 34586                                                 []
# 34448                              ['russian post-rock']
# 34323                                                 []
# 34334                                                 []
# 33389                                                 []
# 34299        ['russian folk metal', 'slavic folk metal']
# 33131                                                 []
#
#        avg_instrumentalness  max_instrumentalness  tracks_count  language  \
# 33046              0.680600              0.968000            10       NaN
# 33384              0.000016              0.000119            10       NaN
# 33424              0.000000              0.000000             1       NaN
# 33690              0.826300              0.947000            10       NaN
# 33333              0.754640              0.950000            10       NaN
# 33112              0.229696              0.764000            10       NaN
# 34537              0.003111              0.015200            10       NaN
# 33764              0.000068              0.000627            10       NaN
# 34432              0.078635              0.701000            10       NaN
# 33249              0.003645              0.036400            10       NaN
# 33413              0.000072              0.000072             1       NaN
# 33978              0.036595              0.164000             5       NaN
# 33754              0.086797              0.583000             8       NaN
# 34586              0.000000              0.000000            10       NaN
# 34448              0.867800              0.976000            10       NaN
# 34323              0.003440              0.029600            10       NaN
# 34334              0.872000              0.872000             1       NaN
# 33389              0.000046              0.000046             1       NaN
# 34299              0.053823              0.411000            10       NaN
# 33131              0.004821              0.032400            10       NaN
#
#        instrumental  notes language_auto
# 33046           NaN    NaN            ru
# 33384           NaN    NaN            ru
# 33424           NaN    NaN            ru
# 33690           NaN    NaN            ru
# 33333           NaN    NaN            ru
# 33112           NaN    NaN            ru
# 34537           NaN    NaN            ru
# 33764           NaN    NaN            ru
# 34432           NaN    NaN            ru
# 33249           NaN    NaN            ru
# 33413           NaN    NaN            ru
# 33978           NaN    NaN            ru
# 33754           NaN    NaN            ru
# 34586           NaN    NaN            ru
# 34448           NaN    NaN            ru
# 34323           NaN    NaN            ru
# 34334           NaN    NaN            ru
# 33389           NaN    NaN            ru
# 34299           NaN    NaN            ru
# 33131           NaN    NaN            ru

# %%
artists[artists["language_auto"] == "china"].sample(20)
# Out:
#          artist_clean genres  avg_instrumentalness  max_instrumentalness  \
# 34913              霍尊     []              0.000005              0.000005
# 34850              花譜     []              0.000007              0.000007
# 34875             語り部     []              0.908800              0.971000
# 34820             楊培安     []              0.001160              0.002320
# 34744             于台煙     []              0.000527              0.001050
# 34896              陳中     []              0.000798              0.002340
# 34933         龍藏ryuzo     []              0.642000              0.867000
# 34748           佐々木恵梨     []              0.000005              0.000009
# 34747            伊藤美来     []              0.703000              0.703000
# 34763             單依純     []              0.000000              0.000000
# 34814             林隆璇     []              0.000000              0.000000
# 34782            後藤邑子     []              0.002880              0.002880
# 34923             鮑比達     []              0.000160              0.000160
# 34866             袁小迪     []              0.000000              0.000000
# 34917             颜慧萍     []              0.000000              0.000000
# 34745             亜咲花     []              0.000000              0.000000
# 34799  李浩瑋 howard lee     []              0.000003              0.000003
# 34756             劉雅麗     []              0.000005              0.000005
# 34862            藤原千花     []              0.000000              0.000000
# 34768             姚蘇蓉     []              0.001830              0.001830
#
#        tracks_count  language  instrumental  notes language_auto
# 34913             1       NaN           NaN    NaN         china
# 34850             1       NaN           NaN    NaN         china
# 34875             5       NaN           NaN    NaN         china
# 34820             2       NaN           NaN    NaN         china
# 34744             2       NaN           NaN    NaN         china
# 34896             3       NaN           NaN    NaN         china
# 34933             2       NaN           NaN    NaN         china
# 34748             2       NaN           NaN    NaN         china
# 34747             1       NaN           NaN    NaN         china
# 34763             1       NaN           NaN    NaN         china
# 34814             1       NaN           NaN    NaN         china
# 34782             1       NaN           NaN    NaN         china
# 34923             1       NaN           NaN    NaN         china
# 34866             1       NaN           NaN    NaN         china
# 34917             1       NaN           NaN    NaN         china
# 34745             1       NaN           NaN    NaN         china
# 34799             1       NaN           NaN    NaN         china
# 34756             1       NaN           NaN    NaN         china
# 34862             1       NaN           NaN    NaN         china
# 34768             2       NaN           NaN    NaN         china

# %%
import os
[f for f in os.listdir(".") if f.endswith(".csv")]
# Out:
# ['artists_unique_normalized.csv',
#  'artists_dictionary_with_auto.csv',
#  'tracks_full_unified.csv',
#  'tracks_with_genres_filled.csv',
#  'artists_dictionary.csv',
#  'all_unique_genres.csv',
#  'artists_manual_review.csv',
#  'tracks_final_ready_normalized_artists.csv',
#  'artists_expanded.csv',
#  'tracks_with_genres.csv',
#  'artists_language_step1.csv',
#  'artists.csv',
#  'tracks_final_ready.csv']

# %%
artists.to_csv(
    "artists_unique_normalized_with_language.csv",
    index=False
)

# %%
import pandas as pd
import ast

artists = pd.read_csv("artists_unique_normalized_with_language.csv")

def parse_genres_safe(x):
    if isinstance(x, list):
        return x
    try:
        return ast.literal_eval(x)
    except:
        return []

artists["genres_parsed"] = artists["genres"].apply(parse_genres_safe)

# %%
type(artists.loc[0, "genres_parsed"])
# Out:
# list

# %%
INSTRUMENTAL_GENRE_KEYWORDS = [
    "instrumental",
    "classical",
    "piano",
    "orchestra",
    "orchestral",
    "symphony",
    "soundtrack",
    "score",
    "neoclassical",
    "ambient",
]

RUSSIAN_GENRE_KEYWORDS = [
    "russian",
    "rus",
]

# %%
def update_language_by_genres(row):
    genres = row["genres_parsed"]

    for g in genres:
        gl = g.lower()
        if any(k in gl for k in INSTRUMENTAL_GENRE_KEYWORDS):
            return "instrumental"

    for g in genres:
        gl = g.lower()
        if any(k in gl for k in RUSSIAN_GENRE_KEYWORDS):
            return "ru"

    return row["language_auto"]

# %%
artists["language_auto"] = artists.apply(
    update_language_by_genres,
    axis=1
)

# %%
artists["language_auto"].value_counts()
# Out:
# language_auto
# other           32442
# ru               2101
# china             202
# instrumental      190
# Name: count, dtype: int64

# %%
def update_language_with_audio(row):
    if row["language_auto"] == "instrumental":
        return "instrumental"

    if (
        row["avg_instrumentalness"] >= 0.6
        or row["max_instrumentalness"] >= 0.8
    ):
        return "instrumental"

    return row["language_auto"]

# %%
artists["language_auto"] = artists.apply(
    update_language_with_audio,
    axis=1
)

# %%
artists["language_auto"].value_counts()
# Out:
# language_auto
# other           24824
# instrumental     8286
# ru               1631
# china             194
# Name: count, dtype: int64

# %%
SEED_RU_LATIN = {
    "morgenstern",
    "face",
    "boulevard depo",
    "kizaru",
    "og buda",
    "scally milano",
    "mayot",
    "seemee",
    "soda luv",
    "markul",
    "big baby tape",
    "lovv66",
    "t-fest",
    "miyagi",
    "yanix",
    "jony",
    "mot",
    "zivert",
    "klava koka",
    "mary gu",
    "demmi",
    "niletto",
    "rasa",
    "katerina",
    "хлеб",
    "ic3peak",
    "pornofilms",
    "louna",
    "slot",
    "bi-2",
    "xena",
    "lizer",
    "mirele",
    "sssshhiiittt!",
    "t.a.t.u.",
    "gone.fludd",
    "ten walls",
    "lil morty",
    "feduk",
    "m'dee",
    "kai angel",
    "trill d",
    "jeembo",
    "bushido zho",
    "alblak 52",
    "maybe baby",
    "saluki",
    "berry",
    "loqeranjean",
    "anikv",
    "tveth",
    "mona",
    "gidra",
    "zoloto",
    "marcel",
    "lostage",
    "smilelikeme",
    "deep-ex-sense",
    "breezzy",
    "whatever",
    "noize mc",
    "anacondaz",
    "the hatters",
    "2rbina 2rista",
    "otyken",
    "savage",
    "kalvados",
    "glebasta spal",
    "pharaoh",
    "pyrokinesis",
    "sqwoz bab",
    "muto",
    "moneyken",
    "termitegod",
    "lemmon juice",
    "swanky tunes",
    "dj smash",
    "swany",
    "kurt92",
    "sted.d",
    "pussykiller",
    "atl",
    "malbec",
    "cakeboy",
    "v $ x v prince",
    "from russia with brat",
    "krestall / courier",
    "dvrklxght",
    "openspace",
    "lil krystalll",
    "goatmilky",
    "lil kavkaz",
    "aigel",
    "netslow",
    "gayazov$ brother$",
    "katya gelmet",
    "janaga",
    "roxette rus",
    "tenderlybane",
    "ivan dorn",
    "jah khalib",
    "elman",
    "slava marlow",
    "zapomni",
    "doni",
    "mufassa",
    "sandr",
    "culture of kefir",
    "roman kazanov",
    "dark side of suburbia",
    "baby melon",
    "sadonray",
    "smarty",
    "cheev",
    "nazima",
    "arut",
    "wensdei",
    "ollane",
    "amri",
    "danchik rezni4eckiy",
    "mister bin",
    "shnyrov",
}

# %%
artists.to_csv(
    "artists_unique_normalized_with_language_genres.csv",
    index=False
)

# %%
import pandas as pd

artists = pd.read_csv("artists_unique_normalized_with_language_genres.csv")

artists["artist_clean"] = artists["artist_clean"].astype(str).str.lower()

before = artists["language_auto"].value_counts()

artists.loc[
    artists["artist_clean"].isin(SEED_RU_LATIN),
    "language_auto"
] = "ru"

after = artists["language_auto"].value_counts()

before
# Out:
# (language_auto
#  other           24824
#  instrumental     8286
#  ru               1631
#  china             194
#  Name: count, dtype: int64,
#  language_auto
#  other           24811
#  instrumental     8285
#  ru               1645
#  china             194
#  Name: count, dtype: int64)

# %%
artists.to_csv(
    "artists_unique_final_with_language_auto_1_3.csv",
    index=False
)

# %%
import pandas as pd

df = pd.read_excel("result.xlsx")

# %%
mask_empty = df["language"].isna() | (df["language"].astype(str).str.strip() == "")

df.loc[mask_empty, "language"] = df.loc[mask_empty, "language_auto"]

df["language"].value_counts()
# Out:
# language
# other           24732
# instrumental     8183
# ru               1661
# china             194
# en                164
# instrumenal         1
# Name: count, dtype: int64

# %%
df["language"] = df["language"].replace("china", "other")

df["language"] = df["language"].replace("instrumenal", "instrumental")

df["language"].value_counts()
# Out:
# language
# other           24926
# instrumental     8184
# ru               1661
# en                164
# Name: count, dtype: int64

# %%
df.to_excel(
    "artists_unique_FINAL.xlsx",
    index=False
)

# %%
artists = pd.read_excel("artists_unique_FINAL.xlsx")
tracks = pd.read_csv("tracks_final_ready_normalized_artists.csv")
# Out:
# /tmp/ipython-input-349227949.py:2: DtypeWarning: Columns (1,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   tracks = pd.read_csv("tracks_final_ready_normalized_artists.csv")

# %%
artists.columns
# Out:
# Index(['artist_clean', 'genres', 'avg_instrumentalness',
#        'max_instrumentalness', 'tracks_count', 'language', 'instrumental',
#        'notes', 'language_auto', 'genres_parsed'],
#       dtype='object')

# %%
tracks.columns
# Out:
# Index(['artist', 'artist_spotify_id', 'name', 'spotify_id', 'duration_ms',
#        'explicit', 'popularity', 'album_type', 'album_name',
#        'album_spotify_id', 'release_date', 'album_popularity', 'key', 'mode',
#        'time_signature', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence',
#        'tempo', 'genres'],
#       dtype='object')

# %%
tracks = tracks.rename(columns={"artist": "artist_clean"})

tracks["artist_clean"] = tracks["artist_clean"].astype(str).str.lower().str.strip()
artists["artist_clean"] = artists["artist_clean"].astype(str).str.lower().str.strip()

# %%
tracks["artist_clean"].head()
# Out:
# 0    ['николай матвеев']
# 1    ['николай матвеев']
# 2    ['николай матвеев']
# 3    ['николай матвеев']
# 4    ['николай матвеев']
# Name: artist_clean, dtype: object

# %%
artists["artist_clean"].head()
# Out:
# 0                   j balvin
# 1                  bad bunny
# 2               daddy yankee
# 3    wolfgang amadeus mozart
# 4                       feid
# Name: artist_clean, dtype: object

# %%
import ast

def parse_artist_list(x):
    if isinstance(x, list):
        return x
    try:
        return ast.literal_eval(x)
    except:
        return []

tracks["artist_list"] = tracks["artist_clean"].apply(parse_artist_list)

# %%
tracks["artist_list"].head()
# Out:
# 0    [николай матвеев]
# 1    [николай матвеев]
# 2    [николай матвеев]
# 3    [николай матвеев]
# 4    [николай матвеев]
# Name: artist_list, dtype: object

# %%
tracks_exploded = tracks.explode("artist_list").reset_index(drop=True)

# %%
tracks_exploded["artist_list"].head()
# Out:
# 0    николай матвеев
# 1    николай матвеев
# 2    николай матвеев
# 3    николай матвеев
# 4    николай матвеев
# Name: artist_list, dtype: object

# %%
tracks_exploded["artist_clean_norm"] = (
    tracks_exploded["artist_list"]
    .astype(str)
    .str.lower()
    .str.strip()
)

# %%
artists["artist_clean_norm"] = (
    artists["artist_clean"]
    .astype(str)
    .str.lower()
    .str.strip()
)

# %%
tracks_exploded = tracks_exploded.merge(
    artists[["artist_clean_norm", "language"]],
    on="artist_clean_norm",
    how="left"
)

# %%
tracks_exploded["language"] = tracks_exploded["language"].fillna("other")

# %%
tracks_final = (
    tracks_exploded
    .groupby(tracks_exploded.index)
    .first()
    .reset_index(drop=True)
)

# %%
tracks_final["language"].value_counts()
# Out:
# language
# other           281302
# instrumental     61104
# en               16411
# ru               14149
# Name: count, dtype: int64

# %%
tracks_final.sample(20)[["artist_list", "language"]]
# Out:
#                     artist_list      language
# 295529            henry purcell  instrumental
# 161269             ernesto fama         other
# 67063             orbit culture         other
# 214895                      yes         other
# 241823           benny mardones         other
# 54270     yung buda;brtt;nikito         other
# 22516        boris petrushansky  instrumental
# 265169                   b-real         other
# 299230       the isley brothers         other
# 235429             lorin maazel  instrumental
# 334150               the weeknd            en
# 170056                the doors         other
# 125305         nikk;avneet kaur         other
# 39981                   attaboy         other
# 225049             ricky martin         other
# 368836                   staind         other
# 212861        leonard bernstein         other
# 133279  bad bunny;bomba estéreo         other
# 253783     manabendra mukherjee         other
# 290175                  tobymac         other

# %%
tracks_final.to_csv(
    "tracks_with_language_FINAL.csv",
    index=False,
    encoding="utf-8-sig"
)
